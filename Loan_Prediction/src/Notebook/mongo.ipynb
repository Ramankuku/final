# %%
import pandas as pd 
import pymongo

# %%
df = pd.read_csv("loan_data.csv")

# %%
df
# Out:
#       Unnamed: 0    ID  Age  Experience  Income  ZIP Code  Family CCAvg  \
# 0              0     1   25           1      49     91108       4  1/60
# 1              1     2   45          19      34     90089       3  1/50
# 2              2     3   39          15      11     94720       1  1/00
# 3              3     4   35           9     100     94112       1  2/70
# 4              4     5   35           8      45     91330       4  1/00
# ...          ...   ...  ...         ...     ...       ...     ...   ...
# 4995        4995  4996   29           3      40     92697       1  1/90
# 4996        4996  4997   30           4      15     92037       4  0/40
# 4997        4997  4998   63          39      24     93023       2  0/30
# 4998        4998  4999   65          40      49     90034       3  0/50
# 4999        4999  5000   28           4      83     92612       3  0/80
#
#          Education  Mortgage Personal Loan Securities Account CD Account  \
# ...

# %%
df.drop(columns=['Unnamed: 0'], inplace=True)

# %%
data = df.to_dict(orient='records')

# %%
DB_NAME = 'Loan-Status-pred'
COLLECTION_NAME = 'Loan-Status-pred-data'
CONNECTION_URL = 'mongodb+srv://raman89765038:AZmmljFeGFLWy6hS@loan-status-pred.fpmw6l5.mongodb.net/?retryWrites=true&w=majority&appName=Loan-Status-pred'

# %%
client = pymongo.MongoClient(CONNECTION_URL)
db_name = client[DB_NAME]
collections = db_name[COLLECTION_NAME]

# %%
rec = collections.insert_many(data)

# %%
df = pd.DataFrame(list(collections.find()))

# %%
df
# Out:
#                            _id    ID  Age  Experience  Income  ZIP Code  \
# 0     681a2933fbfaefe01165be2b     1   25           1      49     91108
# 1     681a2933fbfaefe01165be2c     2   45          19      34     90089
# 2     681a2933fbfaefe01165be2d     3   39          15      11     94720
# 3     681a2933fbfaefe01165be2e     4   35           9     100     94112
# 4     681a2933fbfaefe01165be2f     5   35           8      45     91330
# ...                        ...   ...  ...         ...     ...       ...
# 4995  681a2933fbfaefe01165d1ae  4996   29           3      40     92697
# 4996  681a2933fbfaefe01165d1af  4997   30           4      15     92037
# 4997  681a2933fbfaefe01165d1b0  4998   63          39      24     93023
# 4998  681a2933fbfaefe01165d1b1  4999   65          40      49     90034
# 4999  681a2933fbfaefe01165d1b2  5000   28           4      83     92612
#
#       Family CCAvg     Education  Mortgage Personal Loan Securities Account  \
# ...
